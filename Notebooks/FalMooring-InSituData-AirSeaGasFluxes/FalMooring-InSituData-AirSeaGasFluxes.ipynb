# %% [markdown]
# # Using the Fal mooring in situ data to calculate air-sea CO$_2$ gas fluxes #
#
# ## Introduction
# This notebook explains how we can use the Fal mooring data to calculate air-sea CO$_2$ gas fluxes

# %% [markdown]
# ### Load Relevant Modules
# To begin with the required Python packages are loaded.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from mpl_toolkits.basemap import Basemap
from netCDF4 import Dataset
# Install basemap-data-hires

# %% [markdown]
# ### Loading the mooring data
# Now we need to load the mooring data which is provided as a tab separated variable file (.tsv). And we can then view the first 5 rows of the dataset using the .head(5) command. Alternatively you can view the last 5 rows of the dataset using .tail(5).

# %%
# Load data file
region_data = pd.read_csv('Fal_mooring_flux.tsv', sep='\t', index_col=0)
# Show small proportion of the data
region_data.head(5)
# Out:
#         Lon        Lat          Datetime        Date  Year  Month  Day  Hour  \
# 0 -5.027979  50.216161  14/09/2018 00:00  14/09/2018  2018      9   14     0
# 1 -5.027979  50.216161  14/09/2018 00:00  14/09/2018  2018      9   14     0
# 2 -5.027979  50.216161  14/09/2018 01:00  14/09/2018  2018      9   14     1
# 3 -5.027979  50.216161  14/09/2018 02:00  14/09/2018  2018      9   14     2
# 4 -5.027979  50.216161  14/09/2018 03:00  14/09/2018  2018      9   14     3
#
#    Minute  Second   salinity  sstskin_c   sstskin_k   windu10  \
# 0       0       0  34.417400  16.709000  289.859000  2.057613
# 1       0       0  34.417400  16.709000  289.859000  2.057613
# 2       0       0  34.175967  16.681167  289.831167  2.057613
# 3       0       0  33.936400  16.606000  289.756000  2.572016
# 4       0       0  33.718900  16.542000  289.692000  2.572016
#
#    windu10_moment2  pco2sw_corr_split  pressure_met  pco2_air_noaa_2018  \
# 0         4.233772         500.019450        1024.1            401.3573
# 1         4.233772         488.055048        1024.1            401.3573
# 2         4.233772         550.944840        1023.9            401.3573
# 3         6.615269         588.035046        1023.5            401.3573
# 4         6.615269         627.313939        1022.9            401.3573
#
#     pco2_sst
# 0  16.642000
# 1  16.642000
# 2  16.598000
# 3  16.514667
# 4  16.463000

# %% [markdown]
# ### Preparing to Plot the Recorded Data
# We want to plot a 'time series' of the data that was recorded. One way to show this is to plot 'Days since [first recording]' along the x-axis and the data along the y-axis. The cell below finds the number of days since the first measurement (technically it finds the number of seconds since the first recording and divides this by 86,400) and creates a new column in the Dataframe to show these values.
#
# Note: if your own dataset doesn't have columns for 'Year', 'Month', 'Day', etc. then the below won't work and you need to add this to your dataset. This can be done in Excel (but better to do it Pythonically if possible to prevent Excel making changes to it's own formatting), and see example datasets for the required format.

# %%
# Initialise the new Dataframe column and fill with a hold value
region_data['Days_since'] = 'hold value'

# Produce a datetime object for the first recording 
# - the zeros in the line below show it's the first row (index starts at zero)
start_date = dt.datetime(region_data.loc[0,'Year'],region_data.loc[0,'Month'],region_data.loc[0,'Day'],
                            region_data.loc[0,'Hour'],region_data.loc[0,'Minute'],region_data.loc[0,'Second'])

# Loop over all rows in the Dataframe - i.e from 0 to the length of the Dataframe
for i in range(0,len(region_data)):
    # Get the date time object for the currently indexed recording - indexed by i
    future_date = dt.datetime(region_data.loc[i,'Year'],region_data.loc[i,'Month'],region_data.loc[i,'Day'],
                              region_data.loc[i,'Hour'],region_data.loc[i,'Minute'],region_data.loc[i,'Second'])
    
    # Find difference between current datetime and inital datetime
    day_diff = future_date - start_date
    
    # Fill Dataframe column with time difference in seconds (found using .total_seconds()) 
    # divided by 86400 (proportion of days that have passed)
    region_data.loc[i,'Days_since'] = day_diff.total_seconds()/(60*60*24)

# %% [markdown]
# We can filter the Dataframe to show just the 'Datetime' and 'Days_since' columns. Showing the head can give an idea if the previous cell worked - although a more thorough check is advised if possible depending on Dataframe size.

# %%
# Filter data to 'Datetime' and 'Days_since' columns and show first 5 rows.
region_data[['Datetime', 'Days_since']].head(5)
# Out:
#            Datetime Days_since
# 0  14/09/2018 00:00        0.0
# 1  14/09/2018 00:00        0.0
# 2  14/09/2018 01:00   0.041667
# 3  14/09/2018 02:00   0.083333
# 4  14/09/2018 03:00      0.125

# %% [markdown]
# ### Plotting the Time Series
#
# The Matplotlib .subplots() function is ideal for this and I have used Seaborn to do the actual plotting - these two packages work well together as Seaborn is built on top of Matplotlib, and Seaborn also integrates easily with Pandas Dataframes.
#
# Producing nice looking plots with lovely axes labels and colors etc. can be fiddly, but you can refer to the documentation (and StackOverflow!) for hints and tips.

# %%
import matplotlib.dates as mdates


# Set up a figure with 4 axes on it. Sharex=True means all axes will share the bottom axes (can help with clarity)
fig,ax = plt.subplots(3,2, sharex=True)
# Set figure height and width
fig.set_figheight(15), fig.set_figwidth(15)

### PLOTTING THE DATA ### (- *s indicate a plot keyword below)
# These Seaborn commands state that we want a *lineplot*, where the *data* is coming 
# from our region_data Dataframe, and we chose the *x* & *y* columns that we want, as well
# as the axis (*ax*) we want to plot on (indexed by 0 at the top and 3 at the bottom)
sns.lineplot(data=region_data, x='Date', y='salinity', color='turquoise', ax=ax[0,0])
sns.lineplot(data=region_data, x='Date', y='sstskin_k', color='red', ax=ax[0,1])
sns.lineplot(data=region_data, x='Date', y='windu10', color='green', ax=ax[1,0])
sns.lineplot(data=region_data, x='Date', y='pco2sw_corr_split', color='orange', ax=ax[1,1], hue=region_data["pco2sw_corr_split"].isna().cumsum(), palette=["blue"]*sum(region_data["pco2sw_corr_split"].isna()), legend=False, markers=True)
sns.lineplot(data=region_data, x='Date', y='pressure_met', color='purple', ax=ax[2, 0])
sns.lineplot(data=region_data, x='Date', y='pco2_air_noaa_2018', color='black', ax=ax[2, 1])

# Use WeekdayLocator and DateFormatter to show only weekly dates on x-axis
date_fmt = mdates.DateFormatter('%d-%m-%Y')
week_locator = mdates.WeekdayLocator(byweekday=mdates.MO)
ax[2,0].xaxis.set_major_locator(week_locator)
ax[2,0].xaxis.set_major_formatter(date_fmt)
ax[2,1].xaxis.set_major_locator(week_locator)
ax[2,1].xaxis.set_major_formatter(date_fmt)

# Set x axis label
ax[2,0].set_xlabel('Date', fontsize = 20) 
ax[2,1].set_xlabel('Date', fontsize = 20) 
ax[2,0].set_xticklabels(region_data['Date'], rotation='vertical')
ax[2,1].set_xticklabels(region_data['Date'], rotation='vertical')

# Set x-axis tick labels
tick_locs = ax[2,0].get_xticks() # Get the current tick locations
ax[2,0].set_xticks(tick_locs) # Set the same tick locations
ax[2,0].set_xticklabels(region_data['Date'][::len(region_data['Date'])//len(tick_locs)][:-1], rotation='vertical')
tick_locs = ax[2,1].get_xticks() # Get the current tick locations
ax[2,1].set_xticks(tick_locs) # Set the same tick locations
ax[2,1].set_xticklabels(region_data['Date'][::len(region_data['Date'])//len(tick_locs)][:-1], rotation='vertical')



# Set y label for each axis
ax[0,0].set_ylabel('Salinity', fontsize = 20) 
ax[0,1].set_ylabel('SST (K)', fontsize = 20)
ax[1,0].set_ylabel('Windspeed (m/s)', fontsize = 20)
ax[1,1].set_ylabel('Est.pCO2 (µ atm)', fontsize = 20)
ax[2, 0].set_ylabel('Atm.Pressure (mbar)', fontsize = 20)
ax[2, 1].set_ylabel('Atm.pCO2 (ppm)', fontsize = 20)

# Changes how axis ticks are displayed for last two axes
# - you can comment these out with # to see the effect when removed
ax[0,0].yaxis.set_major_formatter('{x:9<5.2f}')
ax[0,1].yaxis.set_major_formatter('{x:9<5.2f}')
ax[1,0].yaxis.set_major_formatter('{x:9<5.2f}')
ax[1,1].yaxis.set_major_formatter('{x:9<5.2f}')
ax[2,0].yaxis.set_major_formatter('{x:9<5.2f}')
ax[2,1].yaxis.set_major_formatter('{x:9<5.2f}')

# Set a tight layout to remove extra space around the plots
fig.tight_layout()
# Reduce gap between top of figure and the title
fig.subplots_adjust(top=0.95)

# Show figure!
plt.show()
# Out:
# /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning:
# The palette list has fewer values (427) than needed (428) and will cycle, which may produce an uninterpretable plot.
#
# /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/ipykernel_launcher.py:31: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/ipykernel_launcher.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ### Using FluxEngine
# To calcualte the air-sea gas fluxes we are going to be using a bulk formulation of the calculation and using the FluxEngine python module toolbox. So lets check to see which version of the FluxEngine we have installed. It should be at least version 4.0.

# %%
# We primarily use FluxEngine from the command line, but here we can import it just to check the version
import fluxengine as fe
import fluxengine.tools.lib_text2ncdf as nc
print(fe.__version__)
# Out:
# 4.0

# %% [markdown]
# Now we need to convert our .tsv data file in the filetype that the FluxEngine uses which is NetCDF. NetCDF is a standard file format used by many scientific and engineering communities and it allows the data to be compressed and the file can contain the metadata that describes how the data were collected, created and processed.

# %%
# Converting to netCDF
nc.convert_text_to_netcdf(['Fal_mooring_flux.tsv'],startTime='2018-09-14 00:00:00',endTime='2018-11-30 08:00:00',ncOutPath='Fal_mooring.nc',temporalResolution='0 01:00',
    colNames=['salinity', 'sstskin_c', 'sstskin_k', 'windu10', 'windu10_moment2', 'pco2sw_corr_split', 'pressure_met', 'pco2_air_noaa_2018', 'pco2_sst'],
    latProd='Lat',lonProd='Lon',dateIndex=3,parseUnits=False,temporalChunking=1857,limits=[50,51,-6,-5],dateFormatDayFirst=True)
# Out:
# Calculating dimensions.
# The following columns will be extracted:
# 	 salinity
# 	 sstskin_c
# 	 sstskin_k
# 	 windu10
# 	 windu10_moment2
# 	 pco2sw_corr_split
# 	 pressure_met
# 	 pco2_air_noaa_2018
# 	 pco2_sst
# Processing data in file Fal_mooring_flux.tsv
# /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1671: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/tools/lib_text2ncdf.py:98: RuntimeWarning: Mean of empty slice
#   output[coords] = np.nanmean(vals);
# Writing output netCDF file(s)...
# Finished converting text file to netCDF3. There were 0 values which fell outside the specified lat/lon or start/stop time boundaries.
# Number of missing values found: 0

# %% [markdown]
# We now have our NetCDF (version 3) file and we can now use the FluxEngine to calculate the air-sea gas fluxes.

# %%
# Running FluxEngine
# !fe_run.py "Fal_mooring.conf" -s "2018-09-14" -e "2018-12-01" -l
# Out:
# Executing on 'Sayoojs-Air-270.lan' at 25/04/2023 12:07:05
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 14 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 15 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 16 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 17 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 18 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 19 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 20 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 21 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 22 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 23 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 24 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 25 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 26 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 27 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 28 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 29 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 30 Sep 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 01 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 02 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 03 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 04 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 05 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 06 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 07 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 08 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 09 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 10 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 11 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 12 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 13 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 14 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 15 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 16 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 17 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 18 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 19 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 20 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 21 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 22 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 23 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 24 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 25 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 26 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 27 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 28 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 29 Oct 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# ...
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 16 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 17 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 18 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 19 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 20 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 21 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 22 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 23 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 24 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 25 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 26 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 27 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 28 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 29 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 30 Nov 2018 00:00:00 completed successfully.
#
# Couldn't create output directory ''. Do you have write access?
# <class 'FileNotFoundError'> (2, 'No such file or directory')
# Parsing settings file at: /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/fluxengine/core/settings.xml
# (ofluxghg_flux_calc, FluxEngine._load_lon_lat_time): Grid dimensions set to: (1, 1)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the saline skin model (0.100000 psu added to skin salinities)
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SST gradient handling is on, using SSTskin and SSTfnd = SSTskin + 0.170000 for flux calculation (ignoring SSTfnd data in configuration file).
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) Using the RAPID model (from Woolf et al., 2016)
# (rate_parameterisation.py: k_Nightingale2000.__call__) Using the Nightingale et al., 2000 (N00) k parameterisation
# (ofluxghg_flux_calc, FluxEngine._run_fluxengine_) SUCCESS writing file FalEstuary_output.nc
# Flux engine exited with exit code: 0
# 01 Dec 2018 00:00:00 completed successfully.

# %% [markdown]
# The 'completed successfully' message means that we now have the air-sea gas fluxes calculated from the Fal mooring data. The output is currently in a NetCDF file. You can view this using Panoply which is data viewer developed and provided for free by NASA. Alternatively we can extract the data from the NetCDF file and store it back into our original .tsv file as additional columns of data.

# %%
# Appending FluxEngine results
# !fe_append2insitu.py "FalEstuary_output.nc" "Fal_mooring_flux.tsv" "flux_final.tsv" --varsToAppend "OF" "OK3" "OSFC" "OIC1" --dateIndex 3 --lonCol "Lon" --latCol "Lat"
# Out:
# Combining files at  FalEstuary_output.nc and Fal_mooring_flux.tsv
# Row 409 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 409 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 409 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 409 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 410 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 410 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 410 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 410 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 411 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 411 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 411 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 411 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 412 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 412 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 412 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 412 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 413 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 413 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 413 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 413 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 414 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 414 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 414 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 414 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 415 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 415 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 415 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 415 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 416 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 416 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 416 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 416 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 417 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 417 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 417 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 417 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 418 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 418 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 418 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 418 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 419 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 419 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 419 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 419 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 420 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 420 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 420 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 420 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 421 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 421 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 421 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 421 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 422 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 422 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 422 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 422 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 423 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 423 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 423 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 423 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 424 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 424 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 424 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 424 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 425 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 425 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 425 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 425 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 426 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 426 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 426 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 426 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 427 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 427 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 427 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 427 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 428 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 428 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 428 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 428 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 429 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 429 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 429 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 429 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 430 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 430 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 430 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 430 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 431 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 431 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 431 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 431 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 432 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 432 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 432 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 432 Warning: No data found for timestep -247 lat 50.216161 lon -5.027979. nan inserted instead
# Row 433 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 433 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 433 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 433 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 434 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 434 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 434 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 434 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 435 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 435 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 435 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 435 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 436 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 436 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 436 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 436 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 437 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 437 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 437 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 437 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 438 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 438 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 438 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 438 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 439 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 439 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 439 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 439 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 440 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 440 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 440 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 440 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 441 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 441 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 441 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 441 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 442 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 442 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 442 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 442 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 443 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 443 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 443 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 443 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 444 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 444 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 444 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 444 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 445 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 445 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 445 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 445 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 446 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 446 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 446 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 446 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 447 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 447 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 447 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 447 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 448 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 448 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 448 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 448 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 449 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 449 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 449 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 449 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 450 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 450 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 450 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 450 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 451 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 451 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 451 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 451 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 452 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 452 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 452 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 452 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 453 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 453 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 453 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 453 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 454 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 454 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 454 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 454 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 455 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 455 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 455 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 455 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 456 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 456 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 456 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 456 Warning: No data found for timestep -216 lat 50.216161 lon -5.027979. nan inserted instead
# Row 457 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 457 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 457 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 457 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 458 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 458 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 458 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 458 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 459 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 459 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 459 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 459 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 460 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 460 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 460 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 460 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 461 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 461 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 461 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 461 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 462 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 462 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 462 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 462 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 463 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 463 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 463 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 463 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 464 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 464 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 464 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 464 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 465 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 465 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 465 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 465 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 466 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 466 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 466 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 466 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 467 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 467 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 467 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 467 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 468 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 468 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 468 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 468 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 469 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 469 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 469 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 469 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 470 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 470 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 470 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 470 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 471 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 471 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 471 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 471 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 472 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 472 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 472 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 472 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 473 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 473 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 473 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 473 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 474 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 474 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 474 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 474 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 475 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 475 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 475 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 475 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 476 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 476 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 476 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 476 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 477 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 477 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 477 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 477 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 478 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 478 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 478 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 478 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 479 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 479 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 479 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 479 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 480 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 480 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 480 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 480 Warning: No data found for timestep -188 lat 50.216161 lon -5.027979. nan inserted instead
# Row 481 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 481 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 481 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 481 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 482 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 482 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 482 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 482 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 483 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 483 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 483 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 483 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 484 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 484 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 484 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 484 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 485 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 485 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 485 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 485 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 486 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 486 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 486 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 486 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 487 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 487 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 487 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 487 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 488 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 488 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 488 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 488 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 489 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 489 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 489 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 489 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 490 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 490 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 490 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 490 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 491 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 491 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 491 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 491 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 492 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 492 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 492 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 492 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 493 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 493 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 493 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 493 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 494 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 494 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 494 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 494 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 495 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 495 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 495 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 495 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 496 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 496 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 496 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 496 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 497 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 497 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 497 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 497 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 498 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 498 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 498 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 498 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 499 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 499 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 499 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 499 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 500 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 500 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 500 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 500 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 501 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 501 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 501 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 501 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 502 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 502 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 502 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 502 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 503 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 503 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 503 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 503 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 504 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 504 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 504 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 504 Warning: No data found for timestep -157 lat 50.216161 lon -5.027979. nan inserted instead
# Row 505 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 505 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 505 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 505 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 506 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 506 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 506 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 506 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 507 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 507 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 507 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 507 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 508 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 508 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 508 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 508 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 509 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 509 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 509 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 509 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 510 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 510 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 510 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 510 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 511 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 511 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 511 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 511 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 512 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 512 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 512 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 512 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 513 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 513 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 513 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 513 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 514 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 514 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 514 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 514 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 515 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 515 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 515 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 515 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 516 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 516 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 516 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 516 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 517 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 517 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 517 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 517 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 518 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 518 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 518 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 518 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 519 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 519 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 519 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 519 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 520 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 520 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 520 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 520 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 521 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 521 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 521 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 521 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 522 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 522 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 522 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 522 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 523 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 523 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 523 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 523 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 524 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 524 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 524 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 524 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 525 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 525 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 525 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 525 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 526 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 526 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 526 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 526 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 527 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 527 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 527 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 527 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 528 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 528 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 528 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 528 Warning: No data found for timestep -127 lat 50.216161 lon -5.027979. nan inserted instead
# Row 529 Warning: No data found for timestep -96 lat 50.216161 lon -5.027979. nan inserted instead
# Row 529 Warning: No data found for timestep -96 lat 50.216161 lon -5.027979. nan inserted instead
# Row 529 Warning: No data found for timestep -96 lat 50.216161 lon -5.027979. nan inserted instead
# Row 529 Warning: No data found for timestep -96 lat 50.216161 lon -5.027979. nan inserted instead
# ...
# Row 1352 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1353 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1353 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1353 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1353 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1354 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1354 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1354 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1354 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1355 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1355 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1355 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1355 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1356 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1356 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1356 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1356 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1357 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1357 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1357 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1357 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1358 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1358 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1358 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1358 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1359 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1359 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1359 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1359 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1360 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1360 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1360 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1360 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1361 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1361 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1361 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1361 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1362 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1362 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1362 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1362 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1363 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1363 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1363 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1363 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1364 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1364 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1364 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1364 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1365 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1365 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1365 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1365 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1366 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1366 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1366 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1366 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1367 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1367 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1367 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1367 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1368 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1368 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1368 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1368 Warning: No data found for timestep -3 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1417 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1417 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1417 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1417 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1418 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1418 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1418 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1418 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1419 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1419 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1419 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1419 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1420 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1420 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1420 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1420 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1421 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1421 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1421 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1421 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1422 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1422 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1422 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1422 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1423 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1423 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1423 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1423 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1424 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1424 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1424 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1424 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1425 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1425 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1425 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1425 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1426 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1426 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1426 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1426 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1427 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1427 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1427 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1427 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1428 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1428 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1428 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1428 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1429 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1429 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1429 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1429 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1430 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1430 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1430 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1430 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1431 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1431 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1431 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1431 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1432 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1432 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1432 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1432 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1433 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1433 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1433 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1433 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1434 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1434 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1434 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1434 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1435 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1435 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1435 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1435 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1436 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1436 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1436 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1436 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1437 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1437 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1437 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1437 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1438 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1438 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1438 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1438 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1439 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1439 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1439 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1439 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1440 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1440 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1440 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Row 1440 Warning: No data found for timestep 88 lat 50.216161 lon -5.027979. nan inserted instead
# Finished merging ['OF', 'OK3', 'OSFC', 'OIC1'] from FalEstuary_output.nc with Fal_mooring_flux.tsv
# Output written to flux_final.tsv

# %% [markdown]
# We can easily view and plot the air-sea CO 2  gas flux results using some simple python plotting routines.

# %%
# Load merged data
merged_data = pd.read_csv('flux_final.tsv', sep='\t',index_col=0).reset_index(drop=True)

# %%
# View top of merged data
merged_data.head()
# Out:
#         Lon        Lat             Datetime        Date  Year  Month  Day  \
# 0 -5.027979  50.216161  2018-09-14 00:00:00  14/09/2018  2018      9   14
# 1 -5.027979  50.216161  2018-09-14 00:00:00  14/09/2018  2018      9   14
# 2 -5.027979  50.216161  2018-09-14 01:00:00  14/09/2018  2018      9   14
# 3 -5.027979  50.216161  2018-09-14 02:00:00  14/09/2018  2018      9   14
# 4 -5.027979  50.216161  2018-09-14 03:00:00  14/09/2018  2018      9   14
#
#    Hour  Minute  Second  ...   windu10  windu10_moment2  pco2sw_corr_split  \
# 0     0       0       0  ...  2.057613         4.233772         500.019450
# 1     0       0       0  ...  2.057613         4.233772         488.055048
# 2     1       0       0  ...  2.057613         4.233772         550.944840
# 3     2       0       0  ...  2.572016         6.615269         588.035046
# 4     3       0       0  ...  2.572016         6.615269         627.313939
#
#    pressure_met  pco2_air_noaa_2018   pco2_sst  OF [g C m-2 day-1]  \
# 0        1024.1            401.3573  16.642000            0.014376
# 1        1024.1            401.3573  16.642000            0.014376
# 2        1023.9            401.3573  16.598000            0.014376
# 3        1023.5            401.3573  16.514667            0.014376
# 4        1022.9            401.3573  16.463000            0.014376
#
#    OK3 [cm h-1]  OSFC [g m-3]  OIC1 [g m-3]
# 0      1.420482      0.212905      0.170735
# 1      1.420482      0.212905      0.170735
# 2      1.420482      0.212905      0.170735
# 3      1.420482      0.212905      0.170735
# 4      1.420482      0.212905      0.170735
#
# [5 rows x 23 columns]

# %% [markdown]
# We need to add out 'Days_since' to this new merged dataframe:

# %%
# Initialise the new Dataframe column and fill with a hold value
merged_data['Days_since'] = 'hold value'

# Produce a datetime object for the first recording 
# - the zeros in the line below show it's the first row (index starts at zero)
start_date = dt.datetime(merged_data.loc[0,'Year'],merged_data.loc[0,'Month'],merged_data.loc[0,'Day'],
                            merged_data.loc[0,'Hour'],merged_data.loc[0,'Minute'],merged_data.loc[0,'Second'])

# Loop over all rows in the Dataframe - i.e from 0 to the length of the Dataframe
for i in range(0,len(merged_data)):
    # Get the date time object for the currently indexed recording - indexed by i
    future_date = dt.datetime(merged_data.loc[i,'Year'],merged_data.loc[i,'Month'],merged_data.loc[i,'Day'],
                              merged_data.loc[i,'Hour'],merged_data.loc[i,'Minute'],merged_data.loc[i,'Second'])
    
    # Find difference between current datetime and inital datetime
    day_diff = future_date - start_date
    
    # Fill Dataframe column with time difference in seconds (found using .total_seconds()) 
    # divided by 86400 (proportion of days that have passed)
    merged_data.loc[i,'Days_since'] = day_diff.total_seconds()/(60*60*24)

# %%
# Show section of 'Days_since' column for visual check
merged_data[['Datetime', 'Days_since']].head(5)
# Out:
#               Datetime Days_since
# 0  2018-09-14 00:00:00        0.0
# 1  2018-09-14 00:00:00        0.0
# 2  2018-09-14 01:00:00   0.041667
# 3  2018-09-14 02:00:00   0.083333
# 4  2018-09-14 03:00:00      0.125

# %%
print(merged_data.iloc[570])
# Out:
# Lon                             -5.027979
# Lat                             50.216161
# Datetime              2018-07-10 17:00:00
# Date                           07/10/2018
# Year                                 2018
# Month                                  10
# Day                                     7
# Hour                                   17
# Minute                                  0
# Second                                  0
# salinity                        32.034917
# sstskin_c                          14.968
# sstskin_k                         288.118
# windu10                           3.08642
# windu10_moment2                  9.525987
# pco2sw_corr_split                     NaN
# pressure_met                       1024.5
# pco2_air_noaa_2018               405.0718
# pco2_sst                           14.912
# OF [g C m-2 day-1]                    NaN
# OK3 [cm h-1]                          NaN
# OSFC [g m-3]                          NaN
# OIC1 [g m-3]                          NaN
# Days_since                      23.708333
# Name: 570, dtype: object

# %% [markdown]
# ### Plot the Flux

# %%
# Set up a figure with 1 axes
fig, ax = plt.subplots(1, 1, sharex=True, figsize=(20, 10))

# Plot data on the ax object
sns.lineplot(data=merged_data, x='Date', y='OF [g C m-2 day-1]', hue=merged_data["OF [g C m-2 day-1]"].isna().cumsum(), palette=["blue"]*sum(merged_data["OF [g C m-2 day-1]"].isna()), legend=False, markers=True, ax=ax)

# Set plot features 
plt.xlabel(f'Days since {merged_data.loc[0,"Datetime"]}', fontdict={'size':20})
plt.ylabel('Flux [g C m-2 day-1]', fontdict={'size':20})
plt.tick_params(labelsize=15)

# Use WeekdayLocator and DateFormatter to show only weekly dates on x-axis
date_fmt = mdates.DateFormatter('%d-%m-%Y')
week_locator = mdates.WeekdayLocator(byweekday=mdates.MO)
ax.xaxis.set_major_locator(week_locator)
ax.xaxis.set_major_formatter(date_fmt)

# Set x-axis tick labels
tick_locs = ax.get_xticks() # Get the current tick locations
ax.set_xticks(tick_locs) # Set the same tick locations
ax.set_xticklabels(merged_data['Date'][::len(merged_data['Date'])//len(tick_locs)][:-1], rotation='vertical')

# Set x axis label
ax.set_xlabel('Date', fontsize=20) 

# Show figure!
plt.show()
# Out:
# /Users/sayooj/opt/anaconda3/envs/fe_work_env/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning:
# The palette list has fewer values (480) than needed (481) and will cycle, which may produce an uninterpretable plot.
#   """
